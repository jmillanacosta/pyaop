# %%
# For google colab
#!pip install git+https://github.com/jmillanacosta/pyaop.git
#!pip install pandas

# %% [markdown]
# # Data Tables Generation
#
# This notebook demonstrates how to generate various data tables from an `AOPNetwork`.
#
# - **AOP Table**: Key Event relationships and AOP associations
# - **Component Table**: Key Event components and biological processes
# - **Gene Table**: Gene-protein associations with expression data
# - **Compound Table**: Chemical stressor information
# - **Gene Expression Table**: Detailed gene expression data
#
# First we generate an `AOPNetwork`:

# %%
import pandas as pd

from pyaop.aop.builder import AOPNetworkBuilder

# Build a network with various associations
builder = AOPNetworkBuilder()
builder.query_by_identifier(query_type="mie", values="https://identifiers.org/aop.events/1502")
builder.query_genes_for_ke(include_proteins=False)
builder.query_compounds_for_network()
builder.query_components_for_network()
builder.query_organs_for_kes()
builder.query_gene_expression(confidence_level=80)
# Get the populated network
network = builder.network
print(f"Network summary: {network.get_summary()}")
# Out:
# Network summary: {'total_key_events': 12, 'mie_count': 1, 'ao_count': 3, 'ke_count': 8, 'ker_count': 17, 'gene_associations': 26, 'gene_expression_associations': 864, 'compound_associations': 10, 'component_associations': 7, 'organ_associations': 6, 'total_aops': 3}

# %% [markdown]
# Then generate the tables:

# %% [markdown]
# ## 1. AOP Table - Key Event Relationships
#
# The AOP table shows the relationships between Key Events and their associated AOPs:

# %%
# Generate AOP table from the network data model
aop_table = network.aop_table()

print(f"Generated {len(aop_table)} AOP table (KERs) entries")

# Convert to DataFrame for better display
aop_df = pd.DataFrame(aop_table)
print("\nAOP Table columns:", list(aop_df.columns))
print("\nFirst few entries:")
aop_df.head()
# Out:
# Generated 17 AOP table (KERs) entries
#
# AOP Table columns: ['source_id', 'source_label', 'source_type', 'ker_label', 'curie', 'target_id', 'target_label', 'target_type', 'aop_list', 'aop_titles', 'is_connected']
#
# First few entries:
#                                  source_id                    source_label  \
# 0  https://identifiers.org/aop.events/1515          Spermatocyte depletion
# 1  https://identifiers.org/aop.events/1505           Cell cycle, disrupted
# 2  https://identifiers.org/aop.events/1502  Histone deacetylase inhibition
# 3  https://identifiers.org/aop.events/1502  Histone deacetylase inhibition
# 4  https://identifiers.org/aop.events/1502  Histone deacetylase inhibition
#
#   source_type ker_label                   curie  \
# 0          ke      1734  aop.relationships:1734
# 1          ke      1712  aop.relationships:1712
# 2         mie      2010  aop.relationships:2010
# 3         mie      1716  aop.relationships:1716
# 4         mie      1715  aop.relationships:1715
#
#                                  target_id            target_label  \
# 0  https://identifiers.org/aop.events/1506      Testicular atrophy
# 1  https://identifiers.org/aop.events/1262               Apoptosis
# 2  https://identifiers.org/aop.events/1515  Spermatocyte depletion
# 3  https://identifiers.org/aop.events/1262               Apoptosis
# 4  https://identifiers.org/aop.events/1505   Cell cycle, disrupted
#
#   target_type                 aop_list  \
# 0          ao                  AOP:212
# 1          ke                  AOP:212
# 2          ke  AOP:212,AOP:274,AOP:275
# 3          ke  AOP:212,AOP:274,AOP:275
# 4          ke  AOP:212,AOP:274,AOP:275
#
#                                           aop_titles  is_connected
# 0  Histone deacetylase inhibition leading to test...          True
# 1  Histone deacetylase inhibition leading to test...          True
# 2  Histone deacetylase inhibition leading to test...          True
# 3  Histone deacetylase inhibition leading to test...          True
# 4  Histone deacetylase inhibition leading to test...          True

# %% [markdown]
# ## 2. Component Table - Key Event Components
#
# The component table shows the biological processes and objects associated with each Key Event:

# %%
# Generate component table from the network associations
component_table = network.component_table()

print(f"Generated {len(component_table)} component table entries")
component_df = pd.DataFrame(component_table)

component_df
# Out:
# Generated 8 component table entries
#              ke_id ke_number                                   ke_uri  \
# 0  aop.events_1262      1262  https://identifiers.org/aop.events/1262
# 1  aop.events_1503      1503  https://identifiers.org/aop.events/1503
# 2  aop.events_1502      1502  https://identifiers.org/aop.events/1502
# 3  aop.events_1560      1560  https://identifiers.org/aop.events/1560
# 4  aop.events_1239      1239  https://identifiers.org/aop.events/1239
# 5  aop.events_1506      1506  https://identifiers.org/aop.events/1506
# 6  aop.events_1515      1515  https://identifiers.org/aop.events/1515
# 7  aop.events_1505      1505  https://identifiers.org/aop.events/1505
#
#                           ke_name  \
# 0                       Apoptosis
# 1   Histone acetylation, increase
# 2  Histone deacetylase inhibition
# 3   Cell differentiation, altered
# 4        Altered, Gene Expression
# 5              Testicular atrophy
# 6          Spermatocyte depletion
# 7           Cell cycle, disrupted
#
#                                     action_processes  \
# 0  [{'action': 'increased', 'process_id': 'proces...
# 1  [{'action': 'increased', 'process_id': 'proces...
# 2  [{'action': 'decreased', 'process_id': 'proces...
# 3  [{'action': 'abnormal', 'process_id': 'process...
# 4  [{'action': 'abnormal', 'process_id': 'process...
# 5  [{'action': 'increased', 'process_id': 'proces...
# 6                                                 []
# 7  [{'action': 'disrupted', 'process_id': 'proces...
#
#                                               organs  action_process_count  \
# 0  [{'organ_id': 'http://purl.obolibrary.org/obo/...                     1
# 1  [{'organ_id': 'http://purl.obolibrary.org/obo/...                     1
# 2  [{'organ_id': 'http://purl.obolibrary.org/obo/...                     1
# 3                                                 []                     1
# 4                                                 []                     1
# 5  [{'organ_id': 'object_FMA_7210', 'organ_name':...                     1
# 6  [{'organ_id': 'object_FMA_7210', 'organ_name':...                     0
# 7  [{'organ_id': 'http://purl.obolibrary.org/obo/...                     1
#
#    organ_count
# 0            1
# 1            1
# 2            1
# 3            0
# 4            0
# 5            1
# 6            1
# 7            1

# %% [markdown]
# ## 3. Gene Table - Gene-Protein Associations
#
# The gene table shows genes, their protein products, and expression data:

# %%
# Generate gene table from gene associations and expression data
gene_table = network.gene_table()

print(f"Generated {len(gene_table)} gene table entries")

# Convert to DataFrame for analysis
gene_df = pd.DataFrame(gene_table)

gene_df
# Out:
# Generated 19 gene table entries
#                gene protein protein_id               gene_id protein_node_id  \
# 0   ENSG00000048052     N/A        N/A  gene_ENSG00000048052             N/A
# 1   ENSG00000049130     N/A        N/A  gene_ENSG00000049130             N/A
# 2   ENSG00000094631     N/A        N/A  gene_ENSG00000094631             N/A
# 3   ENSG00000109320     N/A        N/A  gene_ENSG00000109320             N/A
# 4   ENSG00000110427     N/A        N/A  gene_ENSG00000110427             N/A
# 5   ENSG00000116478     N/A        N/A  gene_ENSG00000116478             N/A
# 6   ENSG00000118971     N/A        N/A  gene_ENSG00000118971             N/A
# 7   ENSG00000124762     N/A        N/A  gene_ENSG00000124762             N/A
# 8   ENSG00000141510     N/A        N/A  gene_ENSG00000141510             N/A
# 9   ENSG00000147099     N/A        N/A  gene_ENSG00000147099             N/A
# 10  ENSG00000163517     N/A        N/A  gene_ENSG00000163517             N/A
# 11  ENSG00000167815     N/A        N/A  gene_ENSG00000167815             N/A
# 12  ENSG00000171791     N/A        N/A  gene_ENSG00000171791             N/A
# 13  ENSG00000172465     N/A        N/A  gene_ENSG00000172465             N/A
# 14  ENSG00000184260     N/A        N/A  gene_ENSG00000184260             N/A
# 15  ENSG00000184678     N/A        N/A  gene_ENSG00000184678             N/A
# 16  ENSG00000204469     N/A        N/A  gene_ENSG00000204469             N/A
# 17  ENSG00000211918     N/A        N/A  gene_ENSG00000211918             N/A
# 18  ENSG00000229150     N/A        N/A  gene_ENSG00000229150             N/A
#
#                                     expression_organs  \
# 0   testis; testis; testis; testis; testis; testis...
# 1   testis; testis; testis; testis; testis; testis...
# 2   testis; testis; testis; testis; testis; testis...
# 3   testis; testis; testis; testis; testis; testis...
# 4   testis; testis; testis; testis; testis; testis...
# 5   testis; testis; testis; testis; testis; testis...
# 6   testis; testis; testis; testis; testis; testis...
# 7   testis; testis; testis; testis; testis; testis...
# 8   testis; testis; testis; testis; testis; testis...
# 9   testis; testis; testis; testis; testis; testis...
# 10  testis; testis; testis; testis; testis; testis...
# 11  testis; testis; testis; testis; testis; testis...
# 12  testis; testis; testis; testis; testis; testis...
# 13  testis; testis; testis; testis; testis; testis...
# 14  testis; testis; testis; testis; testis; testis...
# 15  testis; testis; testis; testis; testis; testis...
# 16  testis; testis; testis; testis; testis; testis...
# 17  testis; testis; testis; testis; testis; testis...
# 18     testis; testis; testis; testis; testis; testis
#
#                                     expression_levels  \
# 0   89.578460000000006858; 89.578460000000006858; ...
# 1   55.153919999999999391; 55.153919999999999391; ...
# 2   97.346350000000001046; 97.346350000000001046; ...
# 3   83.498869999999996594; 83.498869999999996594; ...
# 4   51.020060000000000855; 51.020060000000000855; ...
# 5   94.644689999999997099; 94.644689999999997099; ...
# 6   73.78740999999999417; 73.78740999999999417; 99...
# 7   96.325220000000001619; 96.325220000000001619; ...
# 8   76.709209999999998786; 76.709209999999998786; ...
# 9   67.42464999999999975; 67.42464999999999975; 72...
# 10  96.925880000000006476; 96.925880000000006476; ...
# 11  92.526009999999999422; 92.526009999999999422; ...
# 12  55.561509999999998399; 55.561509999999998399; ...
# 13  83.880729999999999791; 83.880729999999999791; ...
# 14  57.764670000000002403; 57.764670000000002403; ...
# 15  69.827309999999997103; 69.827309999999997103; ...
# 16  98.792230000000003542; 98.792230000000003542; ...
# 17  6.093449999999999811; 6.093449999999999811; 5....
# 18  47.785049999999998249; 47.785049999999998249; ...
#
#                                 expression_confidence  \
# 0   high confidence level; high confidence level; ...
# 1   high confidence level; high confidence level; ...
# 2   high confidence level; high confidence level; ...
# 3   high confidence level; high confidence level; ...
# 4   high confidence level; high confidence level; ...
# 5   high confidence level; high confidence level; ...
# 6   high confidence level; high confidence level; ...
# 7   high confidence level; high confidence level; ...
# 8   high confidence level; high confidence level; ...
# 9   high confidence level; high confidence level; ...
# 10  high confidence level; high confidence level; ...
# 11  high confidence level; high confidence level; ...
# 12  high confidence level; high confidence level; ...
# 13  high confidence level; high confidence level; ...
# 14  high confidence level; high confidence level; ...
# 15  high confidence level; high confidence level; ...
# 16  high confidence level; high confidence level; ...
# 17  high confidence level; high confidence level; ...
# 18  high confidence level; high confidence level; ...
#
#                                        expression_ids
# 0   http://bgee.org/#EXPRESSION_103607213; http://...
# 1   http://bgee.org/#EXPRESSION_154523557; http://...
# 2   http://bgee.org/#EXPRESSION_40168603; http://b...
# 3   http://bgee.org/#EXPRESSION_162691126; http://...
# 4   http://bgee.org/#EXPRESSION_167787429; http://...
# 5   http://bgee.org/#EXPRESSION_35376778; http://b...
# 6   http://bgee.org/#EXPRESSION_26089081; http://b...
# 7   http://bgee.org/#EXPRESSION_147593673; http://...
# 8   http://bgee.org/#EXPRESSION_47923384; http://b...
# 9   http://bgee.org/#EXPRESSION_219681793; http://...
# 10  http://bgee.org/#EXPRESSION_81921250; http://b...
# 11  http://bgee.org/#EXPRESSION_137532066; http://...
# 12  http://bgee.org/#EXPRESSION_119460163; http://...
# 13  http://bgee.org/#EXPRESSION_141815326; http://...
# 14  http://bgee.org/#EXPRESSION_75740447; http://b...
# 15  http://bgee.org/#EXPRESSION_35118779; http://b...
# 16  http://bgee.org/#EXPRESSION_74463048; http://b...
# 17  http://bgee.org/#EXPRESSION_217384669; http://...
# 18  http://bgee.org/#EXPRESSION_95580622; http://b...

# %% [markdown]
# ## 4. Gene Expression Table - Detailed Expression Data
#
# A dedicated table for gene expression information:

# %%
# Generate detailed gene expression table
gene_expr_table = network.gene_expression_table()

print(f"Generated {len(gene_expr_table)} gene expression entries")

# Convert to DataFrame
gene_expr_df = pd.DataFrame(gene_expr_table)
gene_expr_df
# Out:
# Generated 19 gene expression entries
#             gene_id       gene_label   organ  \
# 0   ENSG00000048052  ENSG00000048052  testis
# 1   ENSG00000049130  ENSG00000049130  testis
# 2   ENSG00000094631  ENSG00000094631  testis
# 3   ENSG00000109320  ENSG00000109320  testis
# 4   ENSG00000110427  ENSG00000110427  testis
# 5   ENSG00000116478  ENSG00000116478  testis
# 6   ENSG00000118971  ENSG00000118971  testis
# 7   ENSG00000124762  ENSG00000124762  testis
# 8   ENSG00000141510  ENSG00000141510  testis
# 9   ENSG00000147099  ENSG00000147099  testis
# 10  ENSG00000163517  ENSG00000163517  testis
# 11  ENSG00000167815  ENSG00000167815  testis
# 12  ENSG00000171791  ENSG00000171791  testis
# 13  ENSG00000172465  ENSG00000172465  testis
# 14  ENSG00000184260  ENSG00000184260  testis
# 15  ENSG00000184678  ENSG00000184678  testis
# 16  ENSG00000204469  ENSG00000204469  testis
# 17  ENSG00000211918  ENSG00000211918  testis
# 18  ENSG00000229150  ENSG00000229150  testis
#
#                                          organ_id       expression_level  \
# 0   http://purl.obolibrary.org/obo/UBERON_0000473  89.578460000000006858
# 1   http://purl.obolibrary.org/obo/UBERON_0000473  55.153919999999999391
# 2   http://purl.obolibrary.org/obo/UBERON_0000473  97.346350000000001046
# 3   http://purl.obolibrary.org/obo/UBERON_0000473  83.498869999999996594
# 4   http://purl.obolibrary.org/obo/UBERON_0000473  51.020060000000000855
# 5   http://purl.obolibrary.org/obo/UBERON_0000473  94.644689999999997099
# 6   http://purl.obolibrary.org/obo/UBERON_0000473   73.78740999999999417
# 7   http://purl.obolibrary.org/obo/UBERON_0000473  96.325220000000001619
# 8   http://purl.obolibrary.org/obo/UBERON_0000473  76.709209999999998786
# 9   http://purl.obolibrary.org/obo/UBERON_0000473   67.42464999999999975
# 10  http://purl.obolibrary.org/obo/UBERON_0000473  96.925880000000006476
# 11  http://purl.obolibrary.org/obo/UBERON_0000473  92.526009999999999422
# 12  http://purl.obolibrary.org/obo/UBERON_0000473  55.561509999999998399
# 13  http://purl.obolibrary.org/obo/UBERON_0000473  83.880729999999999791
# 14  http://purl.obolibrary.org/obo/UBERON_0000473  57.764670000000002403
# 15  http://purl.obolibrary.org/obo/UBERON_0000473  69.827309999999997103
# 16  http://purl.obolibrary.org/obo/UBERON_0000473  98.792230000000003542
# 17  http://purl.obolibrary.org/obo/UBERON_0000473   6.093449999999999811
# 18  http://purl.obolibrary.org/obo/UBERON_0000473  47.785049999999998249
#
#                confidence                 developmental_stage  \
# 0   high confidence level  80 year-old and over stage (human)
# 1   high confidence level  80 year-old and over stage (human)
# 2   high confidence level  80 year-old and over stage (human)
# 3   high confidence level  80 year-old and over stage (human)
# 4   high confidence level  80 year-old and over stage (human)
# 5   high confidence level          third decade stage (human)
# 6   high confidence level  80 year-old and over stage (human)
# 7   high confidence level  80 year-old and over stage (human)
# 8   high confidence level  80 year-old and over stage (human)
# 9   high confidence level  80 year-old and over stage (human)
# 10  high confidence level  80 year-old and over stage (human)
# 11  high confidence level  80 year-old and over stage (human)
# 12  high confidence level  80 year-old and over stage (human)
# 13  high confidence level  80 year-old and over stage (human)
# 14  high confidence level  80 year-old and over stage (human)
# 15  high confidence level  80 year-old and over stage (human)
# 16  high confidence level  80 year-old and over stage (human)
# 17  high confidence level          sixth decade stage (human)
# 18  high confidence level                       nursing stage
#
#                                   expr_id
# 0   http://bgee.org/#EXPRESSION_103607213
# 1   http://bgee.org/#EXPRESSION_154523557
# 2    http://bgee.org/#EXPRESSION_40168603
# 3   http://bgee.org/#EXPRESSION_162691126
# 4   http://bgee.org/#EXPRESSION_167787429
# 5    http://bgee.org/#EXPRESSION_35376778
# 6    http://bgee.org/#EXPRESSION_26089081
# 7   http://bgee.org/#EXPRESSION_147593673
# 8    http://bgee.org/#EXPRESSION_47923384
# 9   http://bgee.org/#EXPRESSION_219681793
# 10   http://bgee.org/#EXPRESSION_81921250
# 11  http://bgee.org/#EXPRESSION_137532066
# 12  http://bgee.org/#EXPRESSION_119460163
# 13  http://bgee.org/#EXPRESSION_141815326
# 14   http://bgee.org/#EXPRESSION_75740447
# 15   http://bgee.org/#EXPRESSION_35118779
# 16   http://bgee.org/#EXPRESSION_74463048
# 17  http://bgee.org/#EXPRESSION_217384669
# 18   http://bgee.org/#EXPRESSION_95580622

# %% [markdown]
# ## 5. Compound Table - Chemical Stressors
#
# The compound table shows chemical compounds that act as stressors in AOPs:

# %%
# Generate compound table from compound associations
compound_table = network.compound_table()

print(f"Generated {len(compound_table)} compound table entries")

# Convert to DataFrame
compound_df = pd.DataFrame(compound_table)
compound_df
# Out:
# Generated 8 compound table entries
#                      compound_name                   chemical_label  \
# 0                         Apicidin                         Apicidin
# 1                         Apicidin                         Apicidin
# 2                         Butyrate                         Butyrate
# 3                           MS-275                           MS-275
# 4               Methoxyacetic acid               Methoxyacetic acid
# 5  Suberoylanilide hydroxamic acid  Suberoylanilide hydroxamic acid
# 6                   Trichostatin A                   Trichostatin A
# 7                    Valproic acid                    Valproic acid
#
#   pubchem_id                                  pubchem_compound   cas_id  \
# 0     467801   https://identifiers.org/pubchem.compound/467801   467801
# 1    6918328  https://identifiers.org/pubchem.compound/6918328  6918328
# 2     104775   https://identifiers.org/pubchem.compound/104775   104775
# 3       4261     https://identifiers.org/pubchem.compound/4261     4261
# 4      12251    https://identifiers.org/pubchem.compound/12251    12251
# 5       5311     https://identifiers.org/pubchem.compound/5311     5311
# 6     444732   https://identifiers.org/pubchem.compound/444732   444732
# 7       3121     https://identifiers.org/pubchem.compound/3121     3121
#
#                               chemical_uri smiles           node_id
# 0  https://identifiers.org/cas/183506-66-3          chemical_467801
# 1  https://identifiers.org/cas/183506-66-3         chemical_6918328
# 2     https://identifiers.org/cas/461-55-2          chemical_104775
# 3  https://identifiers.org/cas/209783-80-2            chemical_4261
# 4     https://identifiers.org/cas/625-45-6           chemical_12251
# 5  https://identifiers.org/cas/149647-78-9            chemical_5311
# 6   https://identifiers.org/cas/58880-19-6          chemical_444732
# 7      https://identifiers.org/cas/99-66-1            chemical_3121

# %% [markdown]
# ## Table Export and Usage
#
# These tables can be easily exported to various formats for further analysis:

# %%
# Example: Export tables to CSV files
import os

# Create output directory
output_dir = "aop_tables"
os.makedirs(output_dir, exist_ok=True)

# Use the convenience methods to get table data
tables_to_export = [
    (aop_df, "aop_relationships.csv"),
    (component_df, "ke_components.csv"),
    (gene_df, "genes_proteins.csv"),
    (gene_expr_df, "gene_expressions.csv"),
    (compound_df, "compounds.csv"),
]

for table_data, filename in tables_to_export:
    filepath = os.path.join(output_dir, filename)
    table_data.to_csv(filepath, index=False)
    print(f"Exported {filename}: {len(table_data)} rows, {len(table_data.columns)} columns")

print(f"\nAll tables exported to {output_dir}/ directory")
# Out:
# Exported aop_relationships.csv: 17 rows, 11 columns
# Exported ke_components.csv: 8 rows, 8 columns
# Exported genes_proteins.csv: 19 rows, 9 columns
# Exported gene_expressions.csv: 19 rows, 8 columns
# Exported compounds.csv: 8 rows, 8 columns
#
# All tables exported to aop_tables/ directory
